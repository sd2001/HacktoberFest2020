# %%
# !pip install numpy pandas matplotlib seaborn plotly

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# Data
import os
for dirname, _, filenames in os.walk('../Datasets'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ../Datasets\matches.csv
# ../Datasets\Readme.md

# %%
matches_data=pd.read_csv('../Datasets/matches.csv')

# %%
matches_data.loc[matches_data.season==2017]
# Out:
# e  2017-04-26       Rising Pune Supergiant
# 29  30    2017   Bangalore  2017-04-27  Royal Challengers Bangalore
# 30  31    2017     Kolkata  2017-04-28             Delhi Daredevils
# 31  32    2017  Chandigarh  2017-04-28          Sunrisers Hyderabad
# 32  33    2017        Pune  2017-04-29       Rising Pune Supergiant
# 33  34    2017      Rajkot  2017-04-29                Gujarat Lions
# 34  35    2017  Chandigarh  2017-04-30             Delhi Daredevils
# 35  36    2017   Hyderabad  2017-04-30          Sunrisers Hyderabad
# 36  37    2017      Mumbai  2017-05-01  Royal Challengers Bangalore
# 37  38    2017        Pune  2017-05-01                Gujarat Lions
# 38  39    2017       Delhi  2017-05-02          Sunrisers Hyderabad
# 39  40    2017     Kolkata  2017-05-03        Kolkata Knight Riders
# 40  41    2017       Delhi  2017-05-04                Gujarat Lions
# 41  42    2017   Bangalore  2017-05-05              Kings XI Punjab
# ...

# %%
biggest_win=matches_data['win_by_runs'].max()
teams_biggest_win=[]

f=matches_data.loc[matches_data['win_by_runs']==biggest_win]

teams_biggest_win.append((str(f['season'].tolist()[0])))
teams_biggest_win.append((str(f['venue'].tolist()[0])))
teams_biggest_win.append((str(f['team1'].tolist()[0])))
teams_biggest_win.append((str(f['team2'].tolist()[0])))
teams_biggest_win.append((str(f['winner'].tolist()[0])))

tie_match_no=matches_data.loc[matches_data['result']=='tie']

# %%
f=matches_data.loc[matches_data['dl_applied']==1]
season_number=f['season'].value_counts()
dl_stadium=f['venue'].value_counts()

# %% [markdown]
# ## Facts For IPL

# %% [markdown]
# ### Favourite Venues

# %%
plt.subplots(figsize=(10,15))
ax=matches_data['venue'].value_counts().sort_values(ascending=True).plot.barh(width=0.9,color=sns.color_palette('inferno',40))
ax.set_xlabel('Grounds')
ax.set_ylabel('count')
plt.show()
# Out:
# &lt;Figure size 720x1080 with 1 Axes&gt;

# %% [markdown]
# ### 5 Mosts Played Venue in the History of IPL from 2008 to 2017

# %%
sns.set_style("darkgrid")
ls=matches_data['venue'].value_counts().sort_values(ascending=False)
ls=ls[:5]
plt.figure(figsize=(20,6))
Most_Played =sns.barplot(ls.index, ls.values, alpha=0.8)

plt.title('Most Played Venue')
plt.ylabel('Count', fontsize=13)
plt.xlabel('Name of the stadiums', fontsize=16)
Most_Played.set_xticklabels(rotation=30, labels=ls.index, fontsize=10)
plt.show()
# Out:
# &lt;Figure size 1440x432 with 1 Axes&gt;

# %% [markdown]
# ### Most Player of the Matches across 9 Seasons

# %%
man_of_match=matches_data['player_of_match'].value_counts()
man_of_match=man_of_match[:10]
sns.set_style("darkgrid")
plt.figure(figsize=(20,6))
man_of_matches=sns.barplot(man_of_match.index, man_of_match.values, alpha=0.8,palette='winter')
plt.title('Most Player Of The Match')
plt.ylabel('Count', fontsize=12)
plt.xlabel('player_of_match', fontsize=12)
man_of_matches.set_xticklabels(rotation=30,labels=man_of_match.index,fontsize=15)
plt.show()
# Out:
# &lt;Figure size 1440x432 with 1 Axes&gt;

# %% [markdown]
# ### Total Matches Played Across Each Season

# %%
plt.figure(figsize=(20,6))
season=sns.countplot(x='season',data=matches_data)
plt.xlabel('Season',fontsize=20)
# Out:
# Text(0.5, 0, &#39;Season&#39;)
# &lt;Figure size 1440x432 with 1 Axes&gt;

# %% [markdown]
# ### Stadium Wise Analysis for Most Played 6 Venues

# %% [markdown]
# #### Feroz Shah Kotla

# %%
Delhi_stadium=matches_data.loc[(matches_data['venue']=='Feroz Shah Kotla') ]
Delhi_stadium_win_by_runs=Delhi_stadium[Delhi_stadium['win_by_runs']>0]
slices=[len(Delhi_stadium_win_by_runs),len(Delhi_stadium)-len(Delhi_stadium_win_by_runs)]
labels=['Batting first','Batting Second']
plt.pie(slices,labels=labels,startangle=90,shadow=1,explode=(0,0.4),autopct='%1.2f%%',colors=['#bf00ff','#66CDAA'])
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# #### Eden Gardens

# %%
Kolkata_stadium=matches_data.loc[(matches_data['venue']=='Eden Gardens') ]
Kolkata_stadium_win_by_runs=Kolkata_stadium[Kolkata_stadium['win_by_runs']>0]# As it is  win by runs this depicts Team batting First Has Won the match
slices=[len(Kolkata_stadium_win_by_runs),len(Kolkata_stadium)-len(Kolkata_stadium_win_by_runs)]
labels=['Batting first','Batting Second']
plt.pie(slices,labels=labels,startangle=90,shadow=1,explode=(0,0.4),autopct='%1.2f%%',colors=['#00bfff','#00ff00'])
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# #### Wankhede Stadium

# %%
Mumbai_stadium=matches_data.loc[(matches_data['venue']=='Wankhede Stadium') ]
Mumbai_stadium_win_by_runs=Mumbai_stadium[Mumbai_stadium['win_by_runs']>0]# As it is  win by runs this depicts Team batting First Has Won the match
slices=[len(Mumbai_stadium_win_by_runs),len(Mumbai_stadium)-len(Mumbai_stadium_win_by_runs)]
labels=['Batting first','Batting Second']
plt.pie(slices,labels=labels,startangle=90,shadow=1,explode=(0,0.4),autopct='%1.2f%%',colors=['#00bfff','#00ff00'])
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# #### M Chinnaswamy Stadium

# %%
M_Chinnaswamy_Stadium=matches_data.loc[(matches_data['venue']=='M Chinnaswamy Stadium') ]
M_Chinnaswamy_Stadium_win_by_runs=M_Chinnaswamy_Stadium[M_Chinnaswamy_Stadium['win_by_runs']>0]# As it is  win by runs this depicts Team batting First Has Won the match
slices=[len(M_Chinnaswamy_Stadium_win_by_runs),len(M_Chinnaswamy_Stadium)-len(M_Chinnaswamy_Stadium_win_by_runs)]
labels=['Batting first','Batting Second']
plt.pie(slices,labels=labels,startangle=90,shadow=1,explode=(0,0.4),autopct='%1.2f%%',colors=['#99ff99','#ffcc99'])
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# #### MA Chidambaram Stadium, Chepauk

# %%
Chennai_stadium=matches_data.loc[(matches_data['venue']=='MA Chidambaram Stadium, Chepauk') ]
Chennai_stadium_win_by_runs=Chennai_stadium[Chennai_stadium['win_by_runs']>0]# As it is  win by runs this depicts Team batting First Has Won the match
slices=[len(Chennai_stadium_win_by_runs),len(Chennai_stadium)-len(Chennai_stadium_win_by_runs)]
labels=['Batting first','Batting Second']
plt.pie(slices,labels=labels,startangle=90,shadow=1,explode=(0,0.4),autopct='%1.2f%%',colors=['#00ffbf','#00ff00'])
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ### Analysis for year 2017

# %% [markdown]
# Toss Winner Analysis in 2017

# %%
match_2017=matches_data[matches_data['season']==2017]
df=match_2017[match_2017['toss_winner']==match_2017['winner']]
slices=[len(df),(59-len(df))]# because Toal 59 matches were played in 2017
labels=['yes','no']
plt.pie(slices,labels=labels,startangle=90,shadow=True,explode=(0,0.05),autopct='%1.2f%%',colors=['#99ff99','#ffcc99'])
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# In 2017, After Winning the Toss

# %%
dfs=matches_data[(matches_data['toss_decision']=='field') & (matches_data['season']==2017) ]
labels=['Bat','Field']
slices=[59-len(dfs),len(dfs)]
plt.pie(slices,labels=labels,startangle=90,shadow=1,explode=(0.2,0.4),autopct='%1.2f%%',colors=['#ff9999','#66b3ff'])
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ### Crucial Observation

# %%
dfd=match_2017[(match_2017['toss_decision']=='field') & (match_2017['toss_winner']==match_2017['winner'])]
labels=['Fielding First Side Won','Fielding Second Side Won']
slices=[len(dfd),59-len(dfd)]
plt.pie(slices,labels=labels,startangle=90,shadow=1,explode=(0.2,0.4),autopct='%1.2f%%',colors=['#ff9999','#66b3ff'])
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ### Is Toss Winner Also the Match Winner?

# %%
df=matches_data[matches_data['toss_winner']==matches_data['winner']]
slices=[len(df), (577-len(df))]
labels=['yes','no']
plt.pie(slices,labels=labels,startangle=90,shadow=True,explode=(0,0.50),autopct='%1.1f%%',colors=['r','g'])
fig=plt.gcf()
fig.set_size_inches(6,6)
plt.show()
# Out:
# &lt;Figure size 432x432 with 1 Axes&gt;

# %% [markdown]
# ### Maximum Man Of Matches

# %%
plt.subplots(figsize=(10,6))

ax=matches_data['player_of_match'].value_counts().head(10).plot.bar(width=0.8,color=sns.color_palette('inferno',10))

ax.set_xlabel('player_of_match')
ax.set_ylabel('count')

for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.15,p.get_height()+0.25))
    plt.show()
# Out:
# &lt;Figure size 720x432 with 1 Axes&gt;

# %% [markdown]
# ### Winners By Year

# %%
print('Winners By Year')
for i in range(2008,2018):
    df=((matches_data[matches_data['season']==i]).iloc[-1])
    print(df[[1,10]].values)
# Out:
# Winners By Year
# [2008 &#39;Rajasthan Royals&#39;]
# [2009 &#39;Deccan Chargers&#39;]
# [2010 &#39;Chennai Super Kings&#39;]
# [2011 &#39;Chennai Super Kings&#39;]
# [2012 &#39;Kolkata Knight Riders&#39;]
# [2013 &#39;Mumbai Indians&#39;]
# [2014 &#39;Kolkata Knight Riders&#39;]
# [2015 &#39;Mumbai Indians&#39;]
# [2016 &#39;Sunrisers Hyderabad&#39;]
# [2017 &#39;Mumbai Indians&#39;]

# %% [markdown]
# ### Favorite Umpires

# %%
plt.subplots(figsize=(10,6))
ump=pd.concat([matches_data['umpire1'],matches_data['umpire2']])
ax=ump.value_counts().head(10).plot.bar(width=0.8,color=sns.color_palette('summer',10))
for p in ax.patches:
    ax.annotate(format(p.get_height()),(p.get_x()+0.15,p.get_height()+0.25))
    plt.show()
# Out:
# &lt;Figure size 720x432 with 1 Axes&gt;

# %% [markdown]
# ## Team1 vs Team2

# %%
def team1_vs_team2(team1,team2):
    mt1=matches_data[((matches_data['team1']==team1)|(matches_data['team2']==team1))&((matches_data['team1']==team2)|(matches_data['team2']==team2))]
    sns.countplot(x='season', hue='winner',data=mt1,palette='Set3')
    plt.xticks(rotation='vertical')
    leg = plt.legend( loc = 'upper center')
    fig=plt.gcf()
    fig.set_size_inches(12,6)
    plt.show()

# %% [markdown]
# ### MI vs CSK

# %%
team1_vs_team2('Chennai Super Kings','Mumbai Indians')
# Out:
# &lt;Figure size 864x432 with 1 Axes&gt;

# %% [markdown]
# ## Matches Won By A Team Against Other Teams

# %%
def comparator(team1):
    teams=['Mumbai Indians','Kolkata Knight Riders','Royal Challengers Bangalore','Deccan Chargers','Chennai Super Kings',
                 'Rajasthan Royals','Delhi Daredevils','Gujarat Lions','Kings XI Punjab',
                 'Sunrisers Hyderabad','Rising Pune Supergiants','Kochi Tuskers Kerala','Pune Warriors','Rising Pune Supergiant']
    teams.remove(team1)
    opponents=teams.copy()
    mt1=matches_data[((matches_data['team1']==team1)|(matches_data['team2']==team1))]
    for i in opponents:
        mask = (((mt1['team1']==i)|(mt1['team2']==i)))&((mt1['team1']==team1)|(mt1['team2']==team1))
        mt2 = mt1.loc[mask, 'winner'].value_counts().to_frame().T
        print(mt2)
    
comparator('Chennai Super Kings')
# Out:
#         Mumbai Indians  Chennai Super Kings
# winner              12                   10
#         Chennai Super Kings  Kolkata Knight Riders
# winner                   10                      6
#         Chennai Super Kings  Royal Challengers Bangalore
# winner                   12                            7
#         Chennai Super Kings  Deccan Chargers
# winner                    6                4
#         Chennai Super Kings  Rajasthan Royals
# winner                   11                 6
#         Chennai Super Kings  Delhi Daredevils
# winner                   11                 5
# Empty DataFrame
# Columns: []
# Index: [winner]
#         Chennai Super Kings  Kings XI Punjab
# winner                   10                7
#         Chennai Super Kings  Sunrisers Hyderabad
# winner                    4                    2
# Empty DataFrame
# Columns: []
# Index: [winner]
#         Chennai Super Kings  Kochi Tuskers Kerala
# ...

# %% [markdown]
# ## Final Match Observations

# %% [markdown]
# ### Which Tems have played and won the maximum finals

# %%
finals=matches_data.drop_duplicates(subset=['season'],keep='last')
finals=finals[['id','season','city','team1','team2','toss_winner','toss_decision','winner']]
most_finals=pd.concat([finals['team1'],finals['team2']]).value_counts().reset_index()
most_finals.rename({'index':'team',0:'count'},axis=1,inplace=True)
xyz=finals['winner'].value_counts().reset_index()
most_finals=most_finals.merge(xyz,left_on='team',right_on='index',how='outer')
most_finals=most_finals.replace(np.NaN,0)
most_finals.drop('index',axis=1,inplace=True)
most_finals.set_index('team',inplace=True)
most_finals.rename({'count':'finals_played','winner':'won_count'},inplace=True,axis=1)
most_finals.plot.bar(width=0.8)
plt.gcf().set_size_inches(10,6)
plt.show()
# Out:
# &lt;Figure size 720x432 with 1 Axes&gt;

# %% [markdown]
# ### Winning Toss == Winning Finals ??

# %%
df=finals[finals['toss_winner']==finals['winner']]
slices=[len(finals),(9-len(df))]
labels=['yes','no']
plt.pie(slices,labels=labels,startangle=90,shadow=True,colors=['green','red'],explode=(0,0.1),autopct='%1.1f%%')
fig = plt.gcf()
fig.set_size_inches(5,5)
plt.show()
# Out:
# &lt;Figure size 360x360 with 1 Axes&gt;
